# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from tqdm import tqdm
matplotlib.use("pgf")
matplotlib.rcParams.update({
    "pgf.texsystem": "pdflatex",
    'font.family': 'serif',
    'text.usetex': True,
    'pgf.rcfonts': False,
})
# %matplotlib widget

# %%
lambda_20mm_true = np.loadtxt("/home/rayhaan/randomWalk_V3/Data/VelocityAlgorithmInvestigation/Gaussian_Fit_True_Lambda_2.0mm.csv", skiprows = 2, delimiter = ", ")
lambda_20mm_track2 = np.loadtxt("/home/rayhaan/randomWalk_V3/Data/VelocityAlgorithmInvestigation/Gaussian_Fit_Track_2point_Lambda_2.0mm.csv", skiprows = 2, delimiter = ", ")
lambda_20mm_track6 = np.loadtxt("/home/rayhaan/randomWalk_V3/Data/VelocityAlgorithmInvestigation/Gaussian_Fit_Track_6point_Lambda_2.0mm.csv", skiprows = 2, delimiter = ", ")
lambda_20mm_trackS = np.loadtxt("/home/rayhaan/randomWalk_V3/Data/VelocityAlgorithmInvestigation/Gaussian_Fit_Track_Spline_Lambda_2.0mm.csv", skiprows = 2, delimiter = ", ")

# %%
lambda_01mm_true = np.loadtxt("/home/rayhaan/randomWalk_V3/Data/VelocityAlgorithmInvestigation/Gaussian_Fit_True_Lambda_0.1mm.csv", skiprows = 2, delimiter = ", ")
lambda_01mm_track2 = np.loadtxt("/home/rayhaan/randomWalk_V3/Data/VelocityAlgorithmInvestigation/Gaussian_Fit_Track_2point_Lambda_0.1mm.csv", skiprows = 2, delimiter = ", ")
lambda_01mm_track6 = np.loadtxt("/home/rayhaan/randomWalk_V3/Data/VelocityAlgorithmInvestigation/Gaussian_Fit_Track_6point_Lambda_0.1mm.csv", skiprows = 2, delimiter = ", ")
lambda_01mm_trackS = np.loadtxt("/home/rayhaan/randomWalk_V3/Data/VelocityAlgorithmInvestigation/Gaussian_Fit_Track_Spline_Lambda_0.1mm.csv", skiprows = 2, delimiter = ", ")

# %%
plt.close("all")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 5))
s = 20

ax1.errorbar(x = lambda_20mm_true[:, 0], y = lambda_20mm_true[:, 1], yerr = lambda_20mm_true[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'k', capsize = 5, label = "Simulation")
ax1.errorbar(x = lambda_20mm_track2[:, 0], y = lambda_20mm_track2[:, 1], yerr = lambda_20mm_track2[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'r', capsize = 5, label = "Track 2 point")
ax1.errorbar(x = lambda_20mm_track6[:, 0], y = lambda_20mm_track6[:, 1], yerr = lambda_20mm_track6[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'g', capsize = 5, label = "Track 6 point")
ax1.errorbar(x = lambda_20mm_trackS[:, 0], y = lambda_20mm_trackS[:, 1], yerr = lambda_20mm_trackS[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'b', capsize = 5, label = "Track Spline")

ax2.errorbar(x = lambda_20mm_true[:, 0], y = lambda_20mm_true[:, 3], yerr = lambda_20mm_true[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'k', capsize = 5, label = "Simulation")
ax2.errorbar(x = lambda_20mm_track2[:, 0], y = lambda_20mm_track2[:, 3], yerr = lambda_20mm_track2[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'r', capsize = 5, label = "Track 2 point")
ax2.errorbar(x = lambda_20mm_track6[:, 0], y = lambda_20mm_track6[:, 3], yerr = lambda_20mm_track6[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'g', capsize = 5, label = "Track 6 point")
ax2.errorbar(x = lambda_20mm_trackS[:, 0], y = lambda_20mm_trackS[:, 3], yerr = lambda_20mm_trackS[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'b', capsize = 5, label = "Track Spline")

ax1.get_xaxis().set_tick_params(direction = "in", which = "both", top = True)
ax1.get_yaxis().set_tick_params(direction = "in", which = "both", right = True)
ax2.get_xaxis().set_tick_params(direction = "in", which = "both", top = True)
ax2.get_yaxis().set_tick_params(direction = "in", which = "both", right = True)

ax1.tick_params(axis="x", labelsize = s - 2) 
ax1.tick_params(axis="y", labelsize = s - 2)
ax2.tick_params(axis="x", labelsize = s - 2) 
ax2.tick_params(axis="y", labelsize = s - 2)

ax1.set_xlim(0.0, 1.4)
ax2.set_xlim(0.0, 1.4)

ax1.set_ylim(-1, 2.2)
ax2.set_ylim(0, 15)

ax1.set_title("(a)", fontsize = s - 2)
ax2.set_title("(b)", fontsize = s - 2)

ax1.set_ylabel(r"$\alpha$ (m$\:$s$^{-1}$)", fontsize = s)
ax2.set_ylabel(r"$\beta$ (m$\:$s$^{-1}$)", fontsize = s)

ax1.set_xlabel(r"$\tau$ (ms)", fontsize = s)
ax2.set_xlabel(r"$\tau$ (ms)", fontsize = s)

fig.tight_layout()
fig.savefig("/home/rayhaan/randomWalk_V3/Plots/Lambda_2.0mm_Alpha_mean_Beta_std.png", dpi = 300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (12, 5))
s = 20

ax1.errorbar(x = lambda_01mm_true[:, 0], y = lambda_01mm_true[:, 1], yerr = lambda_01mm_true[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'k', capsize = 5, label = "Simulation")
ax1.errorbar(x = lambda_01mm_track2[:, 0], y = lambda_01mm_track2[:, 1], yerr = lambda_01mm_track2[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'r', capsize = 5, label = "Track 2 point")
ax1.errorbar(x = lambda_01mm_track6[:, 0], y = lambda_01mm_track6[:, 1], yerr = lambda_01mm_track6[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'g', capsize = 5, label = "Track 6 point")
ax1.errorbar(x = lambda_01mm_trackS[:, 0], y = lambda_01mm_trackS[:, 1], yerr = lambda_01mm_trackS[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'b', capsize = 5, label = "Track Spline")

ax2.errorbar(x = lambda_01mm_true[:, 0], y = lambda_01mm_true[:, 3], yerr = lambda_01mm_true[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'k', capsize = 5, label = "Simulation")
ax2.errorbar(x = lambda_01mm_track2[:, 0], y = lambda_01mm_track2[:, 3], yerr = lambda_01mm_track2[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'r', capsize = 5, label = "Track 2 point")
ax2.errorbar(x = lambda_01mm_track6[:, 0], y = lambda_01mm_track6[:, 3], yerr = lambda_01mm_track6[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'g', capsize = 5, label = "Track 6 point")
ax2.errorbar(x = lambda_01mm_trackS[:, 0], y = lambda_01mm_trackS[:, 3], yerr = lambda_01mm_trackS[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'b', capsize = 5, label = "Track Spline")

ax1.get_xaxis().set_tick_params(direction = "in", which = "both", top = True)
ax1.get_yaxis().set_tick_params(direction = "in", which = "both", right = True)
ax2.get_xaxis().set_tick_params(direction = "in", which = "both", top = True)
ax2.get_yaxis().set_tick_params(direction = "in", which = "both", right = True)

ax1.tick_params(axis="x", labelsize = s - 2) 
ax1.tick_params(axis="y", labelsize = s - 2)
ax2.tick_params(axis="x", labelsize = s - 2) 
ax2.tick_params(axis="y", labelsize = s - 2)

# ax1.set_xlim(0.0, 1.4)
# ax2.set_xlim(0.0, 1.4)

# ax1.set_ylim(-1, 2.2)
# ax2.set_ylim(0, 15)

ax1.set_title("(a)", fontsize = s - 2)
ax2.set_title("(b)", fontsize = s - 2)

ax1.set_ylabel(r"$\alpha$ (m$\:$s$^{-1}$)", fontsize = s)
ax2.set_ylabel(r"$\beta$ (m$\:$s$^{-1}$)", fontsize = s)

ax1.set_xlabel(r"$\tau$ (ms)", fontsize = s)
ax2.set_xlabel(r"$\tau$ (ms)", fontsize = s)

fig.tight_layout()
fig.savefig("/home/rayhaan/randomWalk_V3/Plots/Lambda_0.1mm_Alpha_mean_Beta_std.png", dpi = 300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
plt.close("all")

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize = (12, 10), sharex = "col")
s = 20

ax1.errorbar(x = lambda_01mm_true[:, 0], y = lambda_01mm_true[:, 1], yerr = lambda_01mm_true[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'k', capsize = 5, label = "Simulation")
ax1.errorbar(x = lambda_01mm_trackS[:, 0], y = lambda_01mm_trackS[:, 1], yerr = lambda_01mm_trackS[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'b', capsize = 5, label = "Tracked")

ax2.errorbar(x = lambda_01mm_true[:, 0], y = lambda_01mm_true[:, 3], yerr = lambda_01mm_true[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'k', capsize = 5, label = "Simulation")
ax2.errorbar(x = lambda_01mm_trackS[:, 0], y = lambda_01mm_trackS[:, 3], yerr = lambda_01mm_trackS[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'b', capsize = 5, label = "Tracked")

ax3.errorbar(x = lambda_20mm_true[:, 0], y = lambda_20mm_true[:, 1], yerr = lambda_20mm_true[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'k', capsize = 5, label = "Simulation")
ax3.errorbar(x = lambda_20mm_trackS[:, 0], y = lambda_20mm_trackS[:, 1], yerr = lambda_20mm_trackS[:, 2], linestyle = "None", marker = "o", markersize = 5, color = 'b', capsize = 5, label = "Tracked")

ax4.errorbar(x = lambda_01mm_true[:, 0], y = lambda_01mm_true[:, 3], yerr = lambda_01mm_true[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'k', capsize = 5, label = "Simulation")
ax4.errorbar(x = lambda_01mm_trackS[:, 0], y = lambda_01mm_trackS[:, 3], yerr = lambda_01mm_trackS[:, 4], linestyle = "None", marker = "o", markersize = 5, color = 'b', capsize = 5, label = "Tracked")

ax1.get_xaxis().set_tick_params(direction = "in", which = "both", top = True)
ax1.get_yaxis().set_tick_params(direction = "in", which = "both", right = True)
ax2.get_xaxis().set_tick_params(direction = "in", which = "both", top = True)
ax2.get_yaxis().set_tick_params(direction = "in", which = "both", right = True)
ax3.get_xaxis().set_tick_params(direction = "in", which = "both", top = True)
ax3.get_yaxis().set_tick_params(direction = "in", which = "both", right = True)
ax4.get_xaxis().set_tick_params(direction = "in", which = "both", top = True)
ax4.get_yaxis().set_tick_params(direction = "in", which = "both", right = True)

ax1.tick_params(axis="x", labelsize = s - 2) 
ax1.tick_params(axis="y", labelsize = s - 2)
ax2.tick_params(axis="x", labelsize = s - 2) 
ax2.tick_params(axis="y", labelsize = s - 2)
ax3.tick_params(axis="x", labelsize = s - 2) 
ax3.tick_params(axis="y", labelsize = s - 2)
ax4.tick_params(axis="x", labelsize = s - 2) 
ax4.tick_params(axis="y", labelsize = s - 2)

ax1.set_ylabel(r"$\alpha$ (m$\:$s$^{-1}$)", fontsize = s)
ax2.set_ylabel(r"$\beta$ (m$\:$s$^{-1}$)", fontsize = s)

ax3.set_ylabel(r"$\alpha$ (m$\:$s$^{-1}$)", fontsize = s)
ax4.set_ylabel(r"$\beta$ (m$\:$s$^{-1}$)", fontsize = s)

ax2.set_yscale("log")
ax4.set_yscale("log")

ax1.legend(loc = "upper right", fontsize = s - 2)
ax2.legend(loc = "upper right", fontsize = s - 2)
ax3.legend(loc = "upper right", fontsize = s - 2)
ax4.legend(loc = "upper right", fontsize = s - 2)

ax1.set_xlim(0.0, 1.4)
ax2.set_xlim(0.0, 1.4)
ax3.set_xlim(0.0, 1.4)
ax4.set_xlim(0.0, 1.4)

ax1.set_title(r"(a), $\lambda$ = 2.0 mm", fontsize = s - 2)
ax2.set_title(r"(b), $\lambda$ = 2.0 mm" , fontsize = s - 2)
ax3.set_title(r"(c), $\lambda$ = 0.1 mm", fontsize = s - 2)
ax4.set_title(r"(d), $\lambda$ = 0.1 mm", fontsize = s - 2)

ax3.set_xlabel(r"$\tau$ (ms)", fontsize = s)
ax4.set_xlabel(r"$\tau$ (ms)", fontsize = s)

fig.tight_layout()
fig.savefig("/home/rayhaan/randomWalk_V3/Plots/tau_range_lambda_0.1mm_2.0mm_alpha_beta_spline.png", dpi = 300)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
